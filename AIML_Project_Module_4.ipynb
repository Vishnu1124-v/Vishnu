# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnu1124-v/Vishnu/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Define the function and its derivative
def f(x):
    return x**2 + 5

def df(x):
    return 2*x

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # <-- [REQUIRED] this line is correct

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: 3.425394462494306e-05
# Slope or df(x) value at this point is: 6.850788924988612e-05
# f(x) value or cost at this point is: 5.0000000011733325

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the functions if not already defined
def f(x):
    return x**2 + 5

def df(x):
    return 2 * x

# Create x values for plotting
x_1 = np.linspace(-3, 3, 100)

# Superimpose the gradient descent calculations on plot
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)
plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**3 - 3*x**2 + 2  # Example cubic function

def dg(x):
    return 3*x**2 - 6*x       # Derivative of the above function

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %% [markdown]
# ## Gradient Descent

# %%
def derivative_func(x):
    return 2 * x - 4

initial_guess = 0
result = gradient_descent(derivative_func, initial_guess)

print("Minimum found at:", result[0])
# Out:
# Minimum found at: 1.9766334606471614

# %%
def dg(x):
    return 2 * x - 4  # Derivative of x^2 - 4x + 3

local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.9766784705183265
# Number of steps: 103

# %%
def dg(x):
    return 2 * x - 4  # Derivative of f(x) = x^2 - 4x + 3

local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)

print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.9941687358301219
# Number of steps: 301

# %%
def dg(x):
    return 2 * x - 4  # Derivative of f(x) = x^2 - 4x + 3

local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1)

print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.9764465283323385
# Number of steps: 111

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the cost function (e.g., f(x) = x^2 - 4x + 3)
def g(x):
    return x**2 - 4*x + 3

# Define the derivative of the cost function (f'(x) = 2x - 4)
def dg(x):
    return 2 * x - 4

# Gradient descent function (already defined)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Calling gradient descent function with an initial guess of 0
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0)

# Create a range of x values for plotting
x_2 = np.linspace(-2, 2, 400)

# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1st Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2nd Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Task-4: Define a new cost function and its derivative
def g_task4(x):
    return x**2 + 2*x + 1  # Example cost function: f(x) = x^2 + 2x + 1

def dg_task4(x):
    return 2*x + 2  # Derivative of the cost function: f'(x) = 2x + 2

# Gradient descent function (same as before)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Task-4: Run gradient descent with initial guess of -1
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg_task4, initial_guess=-1)

# Create a range of x values for plotting
x_2 = np.linspace(-3, 1, 400)

# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1st Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-3, 1)
plt.ylim(-2, 5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g_task4(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g_task4(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2nd Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-3, 1)
plt.ylim(-6, 6)
plt.plot(x_2, dg_task4(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# Print results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.0
# Number of steps: 2

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  36

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the cost function and its derivative (same as before)
def g(x):
    return x**2 - 4*x + 3  # Example cost function

def dg(x):
    return 2 * x - 4  # Derivative of the cost function

# Gradient descent function (same as before)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Task-5 and Task-6: Run gradient descent 3 times with different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Experiment with an insane gamma (very large learning rate)
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the results for all the experiments
plt.figure(figsize=[15, 12])

# Low learning rate
plt.subplot(2, 2, 1)
plt.plot(low_gamma[1], g(np.array(low_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(low_gamma[1], g(np.array(low_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('Low Learning Rate (0.0005)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# Mid learning rate
plt.subplot(2, 2, 2)
plt.plot(mid_gamma[1], g(np.array(mid_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(mid_gamma[1], g(np.array(mid_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('Mid Learning Rate (0.001)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# High learning rate
plt.subplot(2, 2, 3)
plt.plot(high_gamma[1], g(np.array(high_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(high_gamma[1], g(np.array(high_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('High Learning Rate (0.002)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# Insane learning rate
plt.subplot(2, 2, 4)
plt.plot(insane_gamma[1], g(np.array(insane_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(insane_gamma[1], g(np.array(insane_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('Insane Learning Rate (0.25)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

plt.tight_layout()
plt.show()

# Print results
print('Low Gamma Result:', low_gamma[0])
print('Mid Gamma Result:', mid_gamma[0])
print('High Gamma Result:', high_gamma[0])
print('Insane Gamma Result:', insane_gamma[0])
# Out:
# Low Gamma Result: 2.9047921471137084
# Mid Gamma Result: 2.81856680468843
# High Gamma Result: 2.669782571272646
# Insane Gamma Result: 1.99990234375

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the cost function (same as before)
def g(x):
    return x**2 - 4*x + 3  # Example cost function

# Define the derivative of the cost function (same as before)
def dg(x):
    return 2 * x - 4  # Derivative of the cost function

# Gradient descent function (modified to return cost values)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]
    cost_list = [g(new_x)]  # List to track the cost values at each iteration

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        cost_list.append(g(new_x))  # Append the current cost to the cost list

        if step_size < precision:
            break

    return new_x, x_list, slope_list, cost_list

# Run gradient descent with initial guess 3 and low gamma (0.0005)
local_min, list_x, deriv_list, cost_list = gradient_descent(derivative_func=dg, initial_guess=3,
                                                            multiplier=0.0005, precision=0.0001, max_iter=100)

# Plot the reduction in cost over iterations
plt.figure(figsize=[10, 6])
plt.plot(cost_list, color='blue', linewidth=3)
plt.title('Reduction in Cost Over Iterations', fontsize=16)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Cost (g(x))', fontsize=14)
plt.grid()
plt.show()

# Print final result
print('Local min occurs at:', local_min)
print('Number of iterations:', len(cost_list))
# Out:
# Local min occurs at: 2.9047921471137084
# Number of iterations: 101

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a new cost function and its derivative for Task-8
def g_task8(x):
    return x**2 - 6*x + 9  # New cost function: f(x) = x^2 - 6x + 9

def dg_task8(x):
    return 2*x - 6  # Derivative: f'(x) = 2x - 6

# Gradient descent function (same as before)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]
    cost_list = [g_task8(new_x)]  # Track cost at each iteration

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        cost_list.append(g_task8(new_x))  # Track cost value

        if step_size < precision:
            break

    return new_x, x_list, slope_list, cost_list

# Run gradient descent with different learning rates for Task-8

# Low learning rate
low_gamma = gradient_descent(derivative_func=dg_task8, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=100)

# Mid learning rate
mid_gamma = gradient_descent(derivative_func=dg_task8, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=100)

# High learning rate
high_gamma = gradient_descent(derivative_func=dg_task8, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=100)

# Plot function and derivative side by side for each learning rate

plt.figure(figsize=[15, 12])

# Plot for Low Gamma
plt.subplot(2, 2, 1)
plt.plot(low_gamma[1], g_task8(np.array(low_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(low_gamma[1], g_task8(np.array(low_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('Low Learning Rate (0.0005)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# Plot for Mid Gamma
plt.subplot(2, 2, 2)
plt.plot(mid_gamma[1], g_task8(np.array(mid_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(mid_gamma[1], g_task8(np.array(mid_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('Mid Learning Rate (0.001)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# Plot for High Gamma
plt.subplot(2, 2, 3)
plt.plot(high_gamma[1], g_task8(np.array(high_gamma[1])), label="Cost Function", color="blue", linewidth=3)
plt.scatter(high_gamma[1], g_task8(np.array(high_gamma[1])), color="red", label="Gradient Descent Steps", s=50)
plt.title('High Learning Rate (0.002)', fontsize=16)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.grid()

# Plot reduction in cost for each iteration
plt.subplot(2, 2, 4)
plt.plot(low_gamma[3], color='blue', label="Low Gamma")
plt.plot(mid_gamma[3], color='green', label="Mid Gamma")
plt.plot(high_gamma[3], color='red', label="High Gamma")
plt.title('Reduction in Cost for Each Iteration', fontsize=16)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Cost (g(x))', fontsize=14)
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# Print final results
print('Low Gamma Result:', low_gamma[0])
print('Mid Gamma Result:', mid_gamma[0])
print('High Gamma Result:', high_gamma[0])
# Out:
# Low Gamma Result: 3.0
# Mid Gamma Result: 3.0
# High Gamma Result: 3.0

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define a cost function f(x, y) (Example: f(x, y) = x^2 + y^2)
def f(x, y):
    return x**2 + y**2  # You can change this to any other cost function

# Create meshgrid for the x and y axes
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

# Generate the cost values (z values)
z_4 = f(x_4, y_4)

# Create the 3D plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

# Set labels
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.7)

# Display the plot
plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(x, y) is:  x**2 + y**2
# Partial derivative wrt x is:  2*y
# Value of f(x,y) at x=1.8 y=1.0 is:  4.24000000000000
# Value of partial derivative wrt x:  3.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.57835979496953e-48 8.76866552760853e-49]
# Minimum occurs at x value of:  6.31343917987813e-49
# Minimum occurs at y value of:  3.50746621104341e-49
# The cost is:  5.21618334996315e-97

# %%
# Partial derivative functions example 4
def fpx(x, y):
    return 2*x  # Partial derivative of f(x, y) = x^2 + y^2 with respect to x

def fpy(x, y):
    return 2*y  # Partial derivative of f(x, y) = x^2 + y^2 with respect to y

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.57835979e-48 8.76866553e-49]
# Minimum occurs at x value of:  6.313439179878134e-49
# Minimum occurs at y value of:  3.507466211043411e-49
# The cost is:  5.216183349963152e-97

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [1.86728201e-19 1.03737889e-19]
# Minimum occurs at x value of:  7.469128023985783e-20
# Minimum occurs at y value of:  4.149515568880998e-20
# The cost is:  7.300635289507557e-39

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.847535148603
# Theta 1: 1.22272646378

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[ 0.96980779]
#  [ 2.31480691]
#  [ 3.78207866]
#  [ 4.76025983]
#  [ 5.86071365]
#  [ 7.81707599]
#  [ 8.79525716]]
# In comparison, the actual y values are
#  [[ 1.7]
#  [ 2.4]
#  [ 3.5]
#  [ 3. ]
#  [ 6.1]
#  [ 9.4]
#  [ 8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [ 0.94796558]
# MSE regression using manual calc is 0.947965575979
# MSE regression is 0.947965575979

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data (you should replace these with your actual data)
nr_thetas = 50  # Number of theta values to test
x_5 = np.linspace(-5, 5, 100)  # x values for linear regression
y_5 = 2*x_5 + 1 + np.random.randn(100) * 0.5  # y values with noise (y = 2x + 1)

# Randomly initialize plot_t0 and plot_t1 (parameters to test)
plot_t0 = np.linspace(-10, 10, nr_thetas).reshape((nr_thetas, 1))  # Intercept
plot_t1 = np.linspace(-10, 10, nr_thetas).reshape((1, nr_thetas))  # Slope

# Mean Squared Error function
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Initialize the plot_cost array
plot_cost = np.zeros((nr_thetas, nr_thetas))

# Calculate the cost (MSE) for every combination of plot_t0 and plot_t1
for i in range(nr_thetas):
    for j in range(nr_thetas):
        y_hat = plot_t0[i, 0] + plot_t1[0, j] * x_5  # Predicted y values
        plot_cost[i, j] = mse(y_5, y_hat)  # Compute cost

# Print the shapes of the arrays
print('Shape of plot_t0:', plot_t0.shape)
print('Shape of plot_t1:', plot_t1.shape)
print('Shape of plot_cost:', plot_cost.shape)

# Plot the cost surface
plt.figure(figsize=(10, 7))
plt.contourf(plot_t0, plot_t1, plot_cost, cmap='coolwarm', levels=20)
plt.colorbar(label="Cost (MSE)")
plt.xlabel('Theta 0 (Intercept)')
plt.ylabel('Theta 1 (Slope)')
plt.title('Cost Function Surface (MSE) for different theta values')
plt.show()
# Out:
# Shape of plot_t0: (50, 1)
# Shape of plot_t1: (1, 50)
# Shape of plot_cost: (50, 50)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-bd23af9baf37> in <cell line: 0>()
#      31 # Plot the cost surface
#      32 plt.figure(figsize=(10, 7))
# ---> 33 plt.contourf(plot_t0, plot_t1, plot_cost, cmap='coolwarm', levels=20)
#      34 plt.colorbar(label="Cost (MSE)")
#      35 plt.xlabel('Theta 0 (Intercept)')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    3179 @_copy_docstring_and_deprecators(Axes.contourf)
#    3180 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3181     __ret = gca().contourf(
#    3182         *args, **({"data": data} if data is not None else {}), **kwargs
#    3183     )
#
# ...

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.6010960719577674
# Min occurs at (i,j): (np.int64(27), np.int64(29))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-831190fba739> in <cell line: 0>()
#       2 ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
#       3 print('Min occurs at (i,j):', ij_min)
# ----> 4 print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
#       5 print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
#
# IndexError: index 29 is out of bounds for axis 0 with size 1

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-9466cc92c6cf> in <cell line: 0>()
#       7
#       8 for i in range(1000):
# ----> 9     thetas = thetas - multiplier * grad(x_5, y_5, thetas)
#      10
#      11     # Append the new values to our numpy arrays
#
# <ipython-input-47-04b79d6f02b7> in grad(x, y, thetas)
#       9     #return np.array([theta0_slope[0], theta1_slope[0]])
#      10     #return np.append(arr=theta0_slope, values=theta1_slope)
# ---> 11     return np.concatenate((theta0_slope, theta1_slope), axis=0)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
